# %% [markdown]
# # Assignment - Day_24

# %% [markdown]
# ## Data Collection and Data Cleaning

# %%
#importing all the packages required
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
data = pd.read_excel('movies.xls')
data
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres  Duration       Budget  User_votes  \
# 0                Drama|History|War       123     385907.0       10718
# 1                      Crime|Drama       110     100000.0           5
# ...

# %% [markdown]
# ## Checking Numerical and categorical data

# %%
#check datatype
data.dtypes
# Out:
# Title                  object
# Year                    int64
# Genres                 object
# Duration                int64
# Budget                float64
# User_votes              int64
# Reviews_by_Users        int64
# Reviews_by_Crtiics    float64
# IMDB_Score            float64
# dtype: object

# %%
# boxplot to describe the data of columns
for i in data.describe().columns:
    sns.boxplot(data[i])
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # 1. Distribution of YEAR

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Year)

# %% [markdown]
# ## 2. Distribution of Genres

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Genres)

# %%
data.Genres
# Out:
# 0                  Drama|History|War
# 1                        Crime|Drama
# 2                  Drama|Romance|War
# 3                       Drama|Sci-Fi
# 4                Crime|Drama|Romance
#                     ...
# 1333                           Drama
# 1334                   Action|Sci-Fi
# 1335      Comedy|Drama|Romance|Sport
# 1336    Action|Comedy|Sci-Fi|Western
# 1337         Action|Adventure|Sci-Fi
# Name: Genres, Length: 1338, dtype: object

# %%
gen=data.groupby('Genres')
gen.count()
# Out:
#                                                     Title  Year  Duration  \
# Genres
# Action                                                  3     3         3
# Action|Adventure                                        4     4         4
# Action|Adventure|Animation|Comedy|Drama|Family|...      1     1         1
# Action|Adventure|Animation|Comedy|Fantasy               1     1         1
# Action|Adventure|Comedy                                 3     3         3
# ...                                                   ...   ...       ...
# Sci-Fi|Thriller                                         3     3         3
# Thriller                                                2     2         2
# Thriller|War                                            1     1         1
# Thriller|Western                                        1     1         1
# Western                                                 8     8         8
#
# ...

# %% [markdown]
# # Distribution of Duration

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Duration)

# %% [markdown]
# # Distribution of budget

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Budget)

# %% [markdown]
# # Distribution of User Votes

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.User_votes)

# %% [markdown]
# # Distribution of Review of Users

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Reviews_by_Users)

# %% [markdown]
# # Distribution of Reviews of Critics

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.Reviews_by_Crtiics)

# %% [markdown]
# # Distribution of IMDB Score

# %%
plt.figure(figsize=(20,10))
sns.countplot(data.IMDB_Score)

# %% [markdown]
# # Checking for missing Values

# %%
# checking for missing values
data.isnull().sum()
# Out:
# Title                  0
# Year                   0
# Genres                 0
# Duration               0
# Budget                57
# User_votes             0
# Reviews_by_Users       0
# Reviews_by_Crtiics     3
# IMDB_Score             0
# dtype: int64
